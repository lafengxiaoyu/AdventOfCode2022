# %% [markdown]
# ## part1

# %%
#                         [R] [J] [W]
#             [R] [N]     [T] [T] [C]
# [R]         [P] [G]     [J] [P] [T]
# [Q]     [C] [M] [V]     [F] [F] [H]
# [G] [P] [M] [S] [Z]     [Z] [C] [Q]
# [P] [C] [P] [Q] [J] [J] [P] [H] [Z]
# [C] [T] [H] [T] [H] [P] [G] [L] [V]
# [F] [W] [B] [L] [P] [D] [L] [N] [G]
#  1   2   3   4   5   6   7   8   9 
    
l = list()

s1 = []
s1.append('F')
s1.append('C')
s1.append('P')
s1.append('G')
s1.append('Q')
s1.append('R')


s2 = []
s2.append('W')
s2.append('T')
s2.append('C')
s2.append('P')

s3 = []
s3.append('B')
s3.append('H')
s3.append('P')
s3.append('M')
s3.append('C')

s4 = []
s4.append('L')
s4.append('T')
s4.append('Q')
s4.append('S')
s4.append('M')
s4.append('P')
s4.append('R')

s5 = []
s5.append('P')
s5.append('H')
s5.append('J')
s5.append('Z')
s5.append('V')
s5.append('G')
s5.append('N')

s6 = []
s6.append('D')
s6.append('P')
s6.append('J')

s7 = []
s7.append('L')
s7.append('G')
s7.append('P')
s7.append('Z')
s7.append('F')
s7.append('J')
s7.append('T')
s7.append('R')

s8 = []
s8.append('N')
s8.append('L')
s8.append('H')
s8.append('C')
s8.append('F')
s8.append('P')
s8.append('T')
s8.append('J')


s9 = []
s9.append('G')
s9.append('V')
s9.append('Z')
s9.append('Q')
s9.append('H')
s9.append('T')
s9.append('C')
s9.append('W')


l.append(s1)
l.append(s2)
l.append(s3)
l.append(s4)
l.append(s5)
l.append(s6)
l.append(s7)
l.append(s8)
l.append(s9)


f = open("./data/day5_input.txt", "rt")

lines = f.readlines()
f.close() 

sumPoints = 0;
for line in lines:
    ll = line.strip().split(" ")
    number = int(ll[1])
    fromP = int(ll[3])
    toP = int(ll[5])
    
    stackFrom = l[fromP - 1]
    stackTo = l[toP - 1]
    
    for i in range(number):
        stackTo.append(stackFrom.pop())
    

for i in range(9):
    print(l[i].pop(), end="")

# %% [markdown]
# ## part2

# %%
#                         [R] [J] [W]
#             [R] [N]     [T] [T] [C]
# [R]         [P] [G]     [J] [P] [T]
# [Q]     [C] [M] [V]     [F] [F] [H]
# [G] [P] [M] [S] [Z]     [Z] [C] [Q]
# [P] [C] [P] [Q] [J] [J] [P] [H] [Z]
# [C] [T] [H] [T] [H] [P] [G] [L] [V]
# [F] [W] [B] [L] [P] [D] [L] [N] [G]
#  1   2   3   4   5   6   7   8   9 
    
l = list()

s1 = []
s1.append('F')
s1.append('C')
s1.append('P')
s1.append('G')
s1.append('Q')
s1.append('R')


s2 = []
s2.append('W')
s2.append('T')
s2.append('C')
s2.append('P')

s3 = []
s3.append('B')
s3.append('H')
s3.append('P')
s3.append('M')
s3.append('C')

s4 = []
s4.append('L')
s4.append('T')
s4.append('Q')
s4.append('S')
s4.append('M')
s4.append('P')
s4.append('R')

s5 = []
s5.append('P')
s5.append('H')
s5.append('J')
s5.append('Z')
s5.append('V')
s5.append('G')
s5.append('N')

s6 = []
s6.append('D')
s6.append('P')
s6.append('J')

s7 = []
s7.append('L')
s7.append('G')
s7.append('P')
s7.append('Z')
s7.append('F')
s7.append('J')
s7.append('T')
s7.append('R')

s8 = []
s8.append('N')
s8.append('L')
s8.append('H')
s8.append('C')
s8.append('F')
s8.append('P')
s8.append('T')
s8.append('J')


s9 = []
s9.append('G')
s9.append('V')
s9.append('Z')
s9.append('Q')
s9.append('H')
s9.append('T')
s9.append('C')
s9.append('W')


l.append(s1)
l.append(s2)
l.append(s3)
l.append(s4)
l.append(s5)
l.append(s6)
l.append(s7)
l.append(s8)
l.append(s9)


f = open("./data/day5_input.txt", "rt")

lines = f.readlines()
f.close() 

sumPoints = 0;
for line in lines:
    ll = line.strip().split(" ")
    number = int(ll[1])
    fromP = int(ll[3])
    toP = int(ll[5])
    
    stackFrom = l[fromP - 1]
    stackTo = l[toP - 1]
    
    index = len(stackFrom) - number
    for i in range(number):
        stackTo.append(stackFrom.pop(index))
    
print(l)
for i in range(9):
    print(l[i].pop(), end="")
